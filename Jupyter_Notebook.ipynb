# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Vidumini Sulochana Perera**<br>
# Associate Python Developer

# %% [markdown]
# *I really love to work with data and statistics and with data science I can find interesting insights*

# %% [markdown]
# <h3>One of My Favorite Areas in Data Science<h3>

# %%
print("Data Science for Trading(Finance)")
# Out:
# Data Science for Trading(Finance)

# %% [markdown]
# <hr>
# <a href="https://ciegescitone.wordpress.com/"> Ciege Scitone </a>
#
# * Planning
# * Executing Plans
# * Balancing
#
# <hr>
#
# ![ciegescitone.png](attachment:d51dc307-dc20-4c57-9a51-133606dd4be8.png)
